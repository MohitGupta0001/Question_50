# %%
def factorial(num:int)->int:
    """
    Return the factorial by recursion method.
    Args(int):Take input numeric value.
    Returns(int): Factorial by recursion method.
    """
    if not isinstance(num,int):
        raise ValueError("Please give input numeric value only.")
    if num == 0 or num == 1:
        return 1
    return num*factorial(num-1)
if __name__ == "__main__":
    try:
        num=int(input("Enter the number:"))
        result=factorial(num)
        print(f"Factorial:{result}")
    except ValueError as e:
        print("Error:",e)
    finally:
        print("Code excuted successfully.")
# Out:
# Enter the number: 5
# Factorial:120
# Code excuted successfully.
